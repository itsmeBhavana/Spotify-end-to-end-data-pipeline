# %%
# !pip install spotipy
# Out:
# ...
#   Obtaining dependency information for redis>=3.5.3 from https://files.pythonhosted.org/packages/0b/34/a01250ac1fc9bf9161e07956d2d580413106ce02d5591470130a25c599e3/redis-5.0.1-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 2.4 MB/s eta 0:00:00a 0:00:01
# ...

# %%
pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/38/1b/e425daceff79695e67d115230bdeb57bbdd6cfff8c46d532e4e64d3dc966/pandas-2.1.1-cp312-cp312-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for numpy>=1.26.0 from https://files.pythonhosted.org/packages/7a/72/6d1cbdf0d770016bc9485f9ef02e73d5cb4cf3c726f8e120b860a403d307/numpy-1.26.0-cp312-cp312-macosx_11_0_arm64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 911.7 kB/s eta 0:00:00a 0:00:01
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 3.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 28.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#Authentication
client_credentials_manager=SpotifyClientCredentials(client_id="ff2f7ce9f57f484b974d3ddb4f37c2a5", client_secret="0719b2f2795347b88b42008c62ce5908")

# %%
#create an object to use and extract data from spotify
#Autherization
sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link="https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

# %%
playlist_URI=playlist_link.split("/")[-1]

# %%
data=sp.playlist_tracks(playlist_URI)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-09-29T08:46:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#        'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#        'id': '5cj0lLjcoR7YOSnhnX0Po5',
#        'name': 'Doja Cat',
#        'type': 'artist',
#        'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
# ...

# %%
#We need Album, song and Artist info from the above API
data['items'][0]
# Out:
# {'added_at': '2023-09-29T08:46:06Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#      'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#      'id': '5cj0lLjcoR7YOSnhnX0Po5',
#      'name': 'Doja Cat',
#      'type': 'artist',
#      'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
# ...

# %%
album_list=[]
for row in data['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']['spotify']
    album_element={'album_id':album_id,'name':album_name,'release_date':album_release_date,'total_tracks':album_total_tracks,
    'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '1bBez9PNvkJPW08bU7NYta',
#   'name': 'Scarlet',
#   'release_date': '2023-09-20',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/1bBez9PNvkJPW08bU7NYta'},
#  {'album_id': '53985D8g3JcGBoULSOYYKX',
#   'name': 'Seven (feat. Latto)',
#   'release_date': '2023-07-14',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'name': 'Lover',
#   'release_date': '2019-08-23',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': '18ogtNq9F7DmMkNYO6Xb4k',
#   'name': 'Strangers',
#   'release_date': '2023-09-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/18ogtNq9F7DmMkNYO6Xb4k'},
#  {'album_id': '0FqAaUEyKCyUNFE1uQPZ7i',
#   'name': 'MAÑANA SERÁ BONITO (BICHOTA SEASON)',
#   'release_date': '2023-08-10',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/0FqAaUEyKCyUNFE1uQPZ7i'},
# ...

# %%
artist_list=[]
for row in data['items']:
    for key, value in row.items():
        if key=='track':
            for artist in value['artists']:
                artist_dict={'artist_id':artist['id'], 'artist_name':artist['name'], 'externam_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '5cj0lLjcoR7YOSnhnX0Po5',
#   'artist_name': 'Doja Cat',
#   'externam_url': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5'},
#  {'artist_id': '6HaGTQPmzraVmaVxvz6EUc',
#   'artist_name': 'Jung Kook',
#   'externam_url': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc'},
#  {'artist_id': '3MdXrJWsbVzdn6fe5JYkSQ',
#   'artist_name': 'Latto',
#   'externam_url': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'externam_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '7uMDnSZyUYNBPLhPMNuaM2',
#   'artist_name': 'Kenya Grace',
#   'externam_url': 'https://api.spotify.com/v1/artists/7uMDnSZyUYNBPLhPMNuaM2'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'externam_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
# ...

# %%
song_list=[]
for row in data['items']:
    song_id=row['track']['id']
    song_name=row['track']['name']
    song_duration=row['track']['duration_ms']
    song_url=row['track']['external_urls']['spotify']
    song_popularity=row['track']['popularity']
    song_added=row['added_at']
    album_id=row['track']['album']['id']
    artist_id=row['track']['album']['artists'][0]['id']
    song_element={'song_id':song_id, 'name':song_name, 'duration':song_duration, 'url':song_url, 'popularity':song_popularity,'song_added':song_added, 'album_id':album_id, 
    'artist_id':artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '56y1jOTK0XSvJzVv9vHQBK',
#   'name': 'Paint The Town Red',
#   'duration': 230480,
#   'url': 'https://open.spotify.com/track/56y1jOTK0XSvJzVv9vHQBK',
#   'popularity': 81,
#   'song_added': '2023-09-29T08:46:06Z',
#   'album_id': '1bBez9PNvkJPW08bU7NYta',
#   'artist_id': '5cj0lLjcoR7YOSnhnX0Po5'},
#  {'song_id': '7x9aauaA9cu6tyfpHnqDLo',
#   'name': 'Seven (feat. Latto) (Explicit Ver.)',
#   'duration': 184400,
#   'url': 'https://open.spotify.com/track/7x9aauaA9cu6tyfpHnqDLo',
#   'popularity': 97,
#   'song_added': '2023-09-29T08:46:06Z',
#   'album_id': '53985D8g3JcGBoULSOYYKX',
#   'artist_id': '6HaGTQPmzraVmaVxvz6EUc'},
#  {'song_id': '1BxfuPKGuaTgP7aM0Bbdwr',
#   'name': 'Cruel Summer',
#   'duration': 178426,
#   'url': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr',
#   'popularity': 98,
#   'song_added': '2023-09-29T08:46:06Z',
#   'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
# ...

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                 name release_date  \
# 0  1bBez9PNvkJPW08bU7NYta                              Scarlet   2023-09-20
# 1  53985D8g3JcGBoULSOYYKX                  Seven (feat. Latto)   2023-07-14
# 2  1NAmidJlEaVgA3MpcPFYGq                                Lover   2019-08-23
# 3  18ogtNq9F7DmMkNYO6Xb4k                            Strangers   2023-09-01
# 4  0FqAaUEyKCyUNFE1uQPZ7i  MAÑANA SERÁ BONITO (BICHOTA SEASON)   2023-08-10
#
#    total_tracks                                                url
# 0            15  https://open.spotify.com/album/1bBez9PNvkJPW08...
# 1             3  https://open.spotify.com/album/53985D8g3JcGBoU...
# 2            18  https://open.spotify.com/album/1NAmidJlEaVgA3M...
# 3             1  https://open.spotify.com/album/18ogtNq9F7DmMkN...
# 4             9  https://open.spotify.com/album/0FqAaUEyKCyUNFE...

# %%
#To drop all the duplicates in the dataframe
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df=pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id   artist_name  \
# 0  5cj0lLjcoR7YOSnhnX0Po5      Doja Cat
# 1  6HaGTQPmzraVmaVxvz6EUc     Jung Kook
# 2  3MdXrJWsbVzdn6fe5JYkSQ         Latto
# 3  06HL4z0CvFAxyc27GXpf02  Taylor Swift
# 4  7uMDnSZyUYNBPLhPMNuaM2   Kenya Grace
#
#                                         externam_url
# 0  https://api.spotify.com/v1/artists/5cj0lLjcoR7...
# 1  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 2  https://api.spotify.com/v1/artists/3MdXrJWsbVz...
# 3  https://api.spotify.com/v1/artists/06HL4z0CvFA...
# 4  https://api.spotify.com/v1/artists/7uMDnSZyUYN...

# %%
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.head()
# Out:
#                 artist_id   artist_name  \
# 0  5cj0lLjcoR7YOSnhnX0Po5      Doja Cat
# 1  6HaGTQPmzraVmaVxvz6EUc     Jung Kook
# 2  3MdXrJWsbVzdn6fe5JYkSQ         Latto
# 3  06HL4z0CvFAxyc27GXpf02  Taylor Swift
# 4  7uMDnSZyUYNBPLhPMNuaM2   Kenya Grace
#
#                                         externam_url
# 0  https://api.spotify.com/v1/artists/5cj0lLjcoR7...
# 1  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 2  https://api.spotify.com/v1/artists/3MdXrJWsbVz...
# 3  https://api.spotify.com/v1/artists/06HL4z0CvFA...
# 4  https://api.spotify.com/v1/artists/7uMDnSZyUYN...

# %%
songs_df=pd.DataFrame.from_dict(song_list)

# %%
songs_df.head()
# Out:
#                   song_id                                 name  duration  \
# 0  56y1jOTK0XSvJzVv9vHQBK                   Paint The Town Red    230480
# 1  7x9aauaA9cu6tyfpHnqDLo  Seven (feat. Latto) (Explicit Ver.)    184400
# 2  1BxfuPKGuaTgP7aM0Bbdwr                         Cruel Summer    178426
# 3  5mjYQaktjmjcMKcUIcqz4s                            Strangers    172964
# 4  5RqSsdzTNPX1uzkmlHCFvK                                QLONA    172797
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/56y1jOTK0XSvJzV...          81
# 1  https://open.spotify.com/track/7x9aauaA9cu6tyf...          97
# 2  https://open.spotify.com/track/1BxfuPKGuaTgP7a...          98
# 3  https://open.spotify.com/track/5mjYQaktjmjcMKc...          94
# 4  https://open.spotify.com/track/5RqSsdzTNPX1uzk...          92
#
#              song_added                album_id               artist_id
# ...

# %%
songs_df=songs_df.drop_duplicates(subset=['song_id'])

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, 0 to 71
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     56 non-null     object
#  1   artist_name   56 non-null     object
#  2   externam_url  56 non-null     object
# dtypes: object(3)
# memory usage: 1.8+ KB

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      45 non-null     object
#  1   name          45 non-null     object
#  2   release_date  45 non-null     object
#  3   total_tracks  45 non-null     int64
#  4   url           45 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df['release_date'].head()
# Out:
# 0   2023-09-20
# 1   2023-07-14
# 2   2019-08-23
# 3   2023-09-01
# 4   2023-08-10
# Name: release_date, dtype: datetime64[ns]

# %%
album_df['release_date']=pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      45 non-null     object
#  1   name          45 non-null     object
#  2   release_date  45 non-null     datetime64[ns]
#  3   total_tracks  45 non-null     int64
#  4   url           45 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.1+ KB

# %%
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   song_id     50 non-null     object
#  1   name        50 non-null     object
#  2   duration    50 non-null     int64
#  3   url         50 non-null     object
#  4   popularity  50 non-null     int64
#  5   song_added  50 non-null     object
#  6   album_id    50 non-null     object
#  7   artist_id   50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ KB

# %%
songs_df['song_added']=pd.to_datetime(songs_df['song_added'])

# %%
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   song_id     50 non-null     object
#  1   name        50 non-null     object
#  2   duration    50 non-null     int64
#  3   url         50 non-null     object
#  4   popularity  50 non-null     int64
#  5   song_added  50 non-null     datetime64[ns, UTC]
#  6   album_id    50 non-null     object
#  7   artist_id   50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB
